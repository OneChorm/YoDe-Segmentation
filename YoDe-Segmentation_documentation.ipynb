# %% [markdown]
# <h3>Download the weights and place them in the appropriate folder</h3>

# %% [markdown]
# 1. Download the DeepLab_v3 model weights: click【[DeepLab_v3](https://drive.google.com/file/d/1ipJNPU5tmCcYDZIbo7_veMu5idQjdbiQ/view?usp=sharing)】<br />
# 2. Download the YOLOv5 model weights: click【[YOLOv5](https://drive.google.com/file/d/1tXX_-RE2sL2U7lRvFfOBUBTIIIN_MhnN/view?usp=sharing)】<br />
# 3. Place the weights in YODE-Segmentation/weights

# %% [markdown]
# <h3>Define the path to the pdf or image</h3>

# %%
# You can place the files you want to process in the YODE_Segmentation/test_img folder
path = os.path.abspath('./test_img')
print(path)
# If you want to place the files that you need to handle in other folders, you need to modify the directory of the read file in the predict_, ular.py
# parser.add_argument(
#     "--source",
#     type=str,
#     default="./test_img",   #CHANGE PATH
#     help="file/dir/URL/glob, 0 for webcam",
# )

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <h3>Run the predict_molecular.py</h3>
# The script is YODov5 and DeepLabv3 and the final denoising calculation together, so only need to run predict_molecule.py, the final extracted chemical molecular structure image in the result_img directory

# %%
# %run predict_molecular.py

# %% [markdown]
# <h5>The chemical molecular structures cut by YOLOv5 model(Show only one)</h5>
#
# ![6ccd5b95514ce5d90f41c15e0f408b4_0.jpg](attachment:6ccd5b95514ce5d90f41c15e0f408b4_0.jpg)

# %% [markdown]
# <h5>The chemical molecular structure masks acquired by DeepLabv3(Show only one)</h5>
#
# ![6ccd5b95514ce5d90f41c15e0f408b4_0.jpg.png](attachment:6ccd5b95514ce5d90f41c15e0f408b4_0.jpg.png)

# %% [markdown]
# <h5>The denoised chemical molecular structure picture is also the final chemical molecular structure map extracted by the model(Show only one)</h5>
#
# ![16ccd5b95514ce5d90f41c15e0f408b4_0.jpg](attachment:16ccd5b95514ce5d90f41c15e0f408b4_0.jpg)
